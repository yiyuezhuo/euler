# %%
data <- read.csv("data.csv")

# %%
data
# Out:
#     id  content des_len diff hit   id.1 solve  t_content
# 1    1   187    25      5    13792  1   537234   85
# 2    2   312    32      5     7571  2   438350  135
# 3    3   111    17      5     6364  3   317208   65
# 4    4   209    20      5     5414  4   285419  101
# 5    5   206    24      5     4627  5   297082   70
# 6    6   431    17      5     4524  6   298805  156
# 7    7   137    16      5     3756  7   256030   62
# 8    8  1255    30      5     4263  8   220371 1071
# 9    9   229    46      5     4090  9   220702  157
# 10  10   105    19      5     3710 10   202710   65
# 11  11  1482    32      5     4511 11   149411 1344
# 12  12   514    27      5     4275 12   137601  290
# 13  13  5190    24      5     3412 13   143861 5123
# 14  14   584    25      5     3791 14   142243  266
# 15  15   209    29      5     2945 15   118253   76
# 16  16   117    22      5     2877 16   145930   87
# 17  17   497    29      5     3182 17    97022  248
# ...

# %%
mod <- lm(log(solve)~id+diff,data=data)

# %%
unlist(mod)
# Out:
# $`coefficients.(Intercept)`
# [1] 11.43688
#
# $coefficients.id
# [1] -0.008123809
#
# $coefficients.diff
# [1] -0.04065105
#
# $residuals.1
# [1] 1.968684
#
# $residuals.2
# [1] 1.773392
#
# $residuals.3
# [1] 1.458056
#
# $residuals.4
# [1] 1.36058
#
# $residuals.5
# [1] 1.408754
#
# $residuals.6
# [1] 1.422661
#
# $residuals.7
# [1] 1.276288
#
# $residuals.8
# [1] 1.134429
#
# $residuals.9
# [1] 1.144054
#
# $residuals.10
# [1] 1.067141
#
# $residuals.11
# [1] 0.7701893
#
# $residuals.12
# [1] 0.6959704
#
# $residuals.13
# [1] 0.7485836
#
# $residuals.14
# [1] 0.7453967
#
# $residuals.15
# [1] 0.5688101
#
# $residuals.16
# [1] 0.7872345
#
# $residuals.17
# [1] 0.387169
#
# $residuals.18
# [1] 0.3645006
#
# $residuals.19
# [1] 0.2956735
#
# $residuals.20
# [1] 0.7075084
#
# $residuals.21
# [1] 0.3846646
#
# $residuals.22
# [1] 0.317988
#
# $residuals.23
# [1] 0.05330711
#
# $residuals.24
# [1] 0.182926
#
# $residuals.25
# [1] 0.4924314
#
# $residuals.26
# [1] -0.1296412
#
# ...

# %%
cutpoint <- 40
data1 <- data[1:cutpoint,]
data2 <- data[(cutpoint+1):nrow(data),]

# %%
mod1 <- lm(log(solve)~id+diff,data=data1)

# %%
mod2 <- lm(log(solve)~id+diff,data=data2)

# %%
summary(mod)
# Out:
# Call:
# lm(formula = log(solve) ~ id + diff, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.6122 -0.2548 -0.0704  0.1462  1.9687
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 11.436884   0.049211  232.41   <2e-16 ***
# id          -0.008124   0.000667  -12.18   <2e-16 ***
# diff        -0.040651   0.001965  -20.68   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.397 on 259 degrees of freedom
# Multiple R-squared:  0.9432,	Adjusted R-squared:  0.9428
# F-statistic:  2150 on 2 and 259 DF,  p-value: < 2.2e-16

# %%
plot(mod$residuals)
# Out:
# plot without title

# %%
summary(mod1)
# Out:
# Call:
# lm(formula = log(solve) ~ id + diff, data = data1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.37976 -0.17272  0.03272  0.14301  0.49836
#
# Coefficients: (1 not defined because of singularities)
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 12.752759   0.070432  181.06   <2e-16 ***
# id          -0.056932   0.002994  -19.02   <2e-16 ***
# diff               NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2186 on 38 degrees of freedom
# Multiple R-squared:  0.9049,	Adjusted R-squared:  0.9024
# F-statistic: 361.6 on 1 and 38 DF,  p-value: < 2.2e-16

# %%
plot(mod1$residuals)
# Out:
# plot without title

# %%
summary(mod2)
# Out:
# Call:
# lm(formula = log(solve) ~ id + diff, data = data2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.27270 -0.07593 -0.02126  0.06451  0.82400
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 10.8479887  0.0226612  478.70   <2e-16 ***
# id          -0.0043876  0.0002377  -18.46   <2e-16 ***
# diff        -0.0422416  0.0006550  -64.50   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1315 on 219 degrees of freedom
# Multiple R-squared:  0.9887,	Adjusted R-squared:  0.9886
# F-statistic:  9591 on 2 and 219 DF,  p-value: < 2.2e-16

# %%
plot(mod2$residuals)
# Out:
# plot without title

# %%
cutpoint <- 80
data1 <- data[1:cutpoint,]
data2 <- data[(cutpoint+1):nrow(data),]

# %%
summary(mod)
# Out:
# Call:
# lm(formula = log(solve) ~ id + diff, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.6122 -0.2548 -0.0704  0.1462  1.9687
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 11.436884   0.049211  232.41   <2e-16 ***
# id          -0.008124   0.000667  -12.18   <2e-16 ***
# diff        -0.040651   0.001965  -20.68   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.397 on 259 degrees of freedom
# Multiple R-squared:  0.9432,	Adjusted R-squared:  0.9428
# F-statistic:  2150 on 2 and 259 DF,  p-value: < 2.2e-16

# %%
plot(mod1$residuals)
# Out:
# plot without title

# %%
summary(mod1)
# Out:
# Call:
# lm(formula = log(solve) ~ id + diff, data = data1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.37976 -0.17272  0.03272  0.14301  0.49836
#
# Coefficients: (1 not defined because of singularities)
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 12.752759   0.070432  181.06   <2e-16 ***
# id          -0.056932   0.002994  -19.02   <2e-16 ***
# diff               NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2186 on 38 degrees of freedom
# Multiple R-squared:  0.9049,	Adjusted R-squared:  0.9024
# F-statistic: 361.6 on 1 and 38 DF,  p-value: < 2.2e-16

# %%
plot(mod1$residuals)
# Out:
# plot without title

# %%
summary(mod2)
# Out:
# Call:
# lm(formula = log(solve) ~ id + diff, data = data2)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.27270 -0.07593 -0.02126  0.06451  0.82400
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) 10.8479887  0.0226612  478.70   <2e-16 ***
# id          -0.0043876  0.0002377  -18.46   <2e-16 ***
# diff        -0.0422416  0.0006550  -64.50   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1315 on 219 degrees of freedom
# Multiple R-squared:  0.9887,	Adjusted R-squared:  0.9886
# F-statistic:  9591 on 2 and 219 DF,  p-value: < 2.2e-16

# %%
plot(mod2$residuals)
# Out:
# plot without title
